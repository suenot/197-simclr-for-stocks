# %% [markdown]
# # SimCLR for Stocks: Self-Supervised Representations
# Learning to extract meaningful stock features from unlabeled data through contrastive learning.

# %%
from augmentations import apply_simclr_augmentations
from model import CNN1DEncoder, SimCLR
print('SimCLR Components Ready.')
